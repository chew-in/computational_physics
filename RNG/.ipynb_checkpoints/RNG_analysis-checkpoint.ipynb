# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties
from matplotlib.ticker import StrMethodFormatter

# %% [markdown]
# ## formatting

# %%
# Define Tableau 10 Colors
tableau_colors = [
    (31, 119, 180),  # Blue
    (255, 127, 14),  # Orange
    (44, 160, 44),   # Green
    (214, 39, 40),   # Red
    (148, 103, 189), # Purple
    (140, 86, 75),   # Brown
    (227, 119, 194), # Pink
    (127, 127, 127), # Gray
    (188, 189, 34),  # Yellow
    (23, 190, 207),  # Cyan
]

# Normalize RGB values to range [0, 1]
tableau_colors = [(r / 255, g / 255, b / 255) for r, g, b in tableau_colors]

# %%
font = {'family': 'Georgia', 'color':  'black', 'weight': 'normal', 'size': 20}
title_font = {'family': 'Georgia', 'color':  'black', 'weight': 'bold', 'style': 'italic', 'size': 20}
suptitle_font = FontProperties(family='Georgia', weight='bold', size=22)
legend_font = FontProperties(family='Georgia', weight='normal', size=16)
tick_font = {'family': 'Georgia', 'size': 18}

# %% [markdown]
# ## data

# %%
data_randm = pd.read_csv('rndtest_randm.out1', header=None, names=['col1'])
df_randm = pd.DataFrame(data_randm)

data_rand = pd.read_csv('rndtest_rand.out1', header=None, names=['col1'])
df_rand = pd.DataFrame(data_rand)

data_random_number = pd.read_csv('rndtest_random_number.out1', header=None, names=['col1'])
df_random_number = pd.DataFrame(data_random_number)

data_randu = pd.read_csv('rndtest_randu.out1', header=None, names=['col1'])
df_randu = pd.DataFrame(data_randu)

# %%
df_randm['col1']
# Out:
# 0                   1   91.0000000       10.0000000
# 1                   2   75.0000000       10.0000000
# 2                   3   106.000000       10.0000000
# 3                   4   85.0000000       10.0000000
# 4                   5   88.0000000       10.0000000
#                               ...
# 99995           99996   111.000000       10.0000000
# 99996           99997   119.000000       10.0000000
# 99997           99998   102.000000       10.0000000
# 99998           99999   106.000000       10.0000000
# 99999          100000   125.000000       10.0000000
# Name: col1, Length: 100000, dtype: object

# %%
df_randm[['bin#', 'hits', 'std']] = df_randm['col1'].str.split(expand=True)
# Convert the columns to appropriate numeric types if needed
df_randm['bin#'] = df_randm['bin#'].astype(int)
df_randm['hits'] = df_randm['hits'].astype(float)
df_randm['stde'] = df_randm['std'].astype(float)
df_randm.drop(columns=['col1'], inplace=True)

df_randu[['bin#', 'hits', 'std']] = df_randu['col1'].str.split(expand=True)
# Convert the columns to appropriate numeric types if needed
df_randu['bin#'] = df_randu['bin#'].astype(int)
df_randu['hits'] = df_randu['hits'].astype(float)
df_randu['stde'] = df_randu['std'].astype(float)
df_randu.drop(columns=['col1'], inplace=True)

df_rand[['bin#', 'hits', 'std']] = df_rand['col1'].str.split(expand=True)
# Convert the columns to appropriate numeric types if needed
df_rand['bin#'] = df_rand['bin#'].astype(int)
df_rand['hits'] = df_rand['hits'].astype(float)
df_rand['stde'] = df_rand['std'].astype(float)
df_rand.drop(columns=['col1'], inplace=True)

df_random_number[['bin#', 'hits', 'std']] = df_random_number['col1'].str.split(expand=True)
# Convert the columns to appropriate numeric types if needed
df_random_number['bin#'] = df_random_number['bin#'].astype(int)
df_random_number['hits'] = df_random_number['hits'].astype(float)
df_random_number['stde'] = df_random_number['std'].astype(float)
df_random_number.drop(columns=['col1'], inplace=True)

# %%
# Create a scatter plot
plt.figure(figsize=(8, 8))
ax = plt.gca()
plt.scatter(df_randm['bin#'], df_randm['hits'], marker='o', color='blue', s=10, \
            alpha=0.5, label='Data Points')

# Set limits for the x-axis and y-axis
plt.ylim(0, 170)  # Set the y-axis limits

font = {'family': 'Georgia', 'color':  'black', 'weight': 'normal', 'size': 20}

plt.title('Histogram of Random Numbers, randm', fontdict=font)
plt.xlabel('Bin Index', fontdict=font)
plt.ylabel('Hit Count', fontdict=font)
# plt.legend()
# plt.grid(True)

# Get the current figure and set its face color to white, for darkmode readability
plt.gcf().set_facecolor('white')

# Customize tick sizes
ax.tick_params(axis='both', which='major', labelsize=18, length=6)  # Adjust label size and tick length

plt.savefig('scatter_example.png') 
plt.show()

# %%
# Create a figure with a specific size (e.g., 10 inches wide and 8 inches tall)
fig, axs = plt.subplots(2, 2, figsize=(16, 16))

# Create individual plots for each subplot
axs[0, 0].scatter(df_rand['bin#'], df_rand['hits'], marker='o', color='blue', s=10, \
            alpha=0.5, label='Data Points')
axs[0, 0].set_ylim(0, 170)  # Set the y-axis limits
axs[0, 0].set_title('rand', fontdict=title_font)
axs[0, 0].set_xlabel('Bin Index', fontdict=font)
axs[0, 0].set_ylabel('Hit Count', fontdict=font)
axs[0, 0].set_xticklabels(ax.get_xticks(), fontdict=tick_font)
axs[0, 0].set_yticklabels(ax.get_yticks(), fontdict=tick_font)
axs[0, 0].xaxis.set_major_formatter(StrMethodFormatter('{x:.0f}'))
axs[0, 0].yaxis.set_major_formatter(StrMethodFormatter('{x:.0f}'))

axs[0, 1].scatter(df_randm['bin#'], df_randm['hits'], marker='o', color='blue', s=10, \
            alpha=0.5, label='Data Points')
axs[0, 1].set_ylim(0, 170)  # Set the y-axis limits
axs[0, 1].set_title('randm', fontdict=title_font)
axs[0, 1].set_xlabel('Bin Index', fontdict=font)
axs[0, 1].set_ylabel('Hit Count', fontdict=font)
axs[0, 1].tick_params(axis='both', which='major', labelsize=18, length=6)  # Adjust label size and tick length
axs[0, 1].set_xticklabels(ax.get_xticks(), fontdict=tick_font)
axs[0, 1].set_yticklabels(ax.get_yticks(), fontdict=tick_font)
axs[0, 1].xaxis.set_major_formatter(StrMethodFormatter('{x:.0f}'))
axs[0, 1].yaxis.set_major_formatter(StrMethodFormatter('{x:.0f}'))

axs[1, 0].scatter(df_randu['bin#'], df_randu['hits'], marker='o', color='blue', s=10, \
            alpha=0.5, label='Data Points')
axs[1, 0].set_ylim(0, 170)  # Set the y-axis limits
axs[1, 0].set_title('randu', fontdict=title_font)
axs[1, 0].set_xlabel('Bin Index', fontdict=font)
axs[1, 0].set_ylabel('Hit Count', fontdict=font)
axs[1, 0].tick_params(axis='both', which='major', labelsize=18, length=6)  # Adjust label size and tick length
axs[1, 0].set_xticklabels(ax.get_xticks(), fontdict=tick_font)
axs[1, 0].set_yticklabels(ax.get_yticks(), fontdict=tick_font)
axs[1, 0].xaxis.set_major_formatter(StrMethodFormatter('{x:.0f}'))
axs[1, 0].yaxis.set_major_formatter(StrMethodFormatter('{x:.0f}'))

axs[1, 1].scatter(df_random_number['bin#'], df_random_number['hits'], marker='o', color='blue', s=10, \
            alpha=0.5, label='Data Points')
axs[1, 1].set_ylim(0, 170)  # Set the y-axis limits
axs[1, 1].set_title('random_number', fontdict=title_font)
axs[1, 1].set_xlabel('Bin Index', fontdict=font)
axs[1, 1].set_ylabel('Hit Count', fontdict=font)
axs[1, 1].tick_params(axis='both', which='major', labelsize=18, length=6)  # Adjust label size and tick length
axs[1, 1].set_xticklabels(ax.get_xticks(), fontdict=tick_font)
axs[1, 1].set_yticklabels(ax.get_yticks(), fontdict=tick_font)
axs[1, 1].xaxis.set_major_formatter(StrMethodFormatter('{x:.0f}'))
axs[1, 1].yaxis.set_major_formatter(StrMethodFormatter('{x:.0f}'))

fig.suptitle('Histogram of Random Numbers', fontproperties=suptitle_font, y=0.93)

plt.gcf().set_facecolor('white')
# plt.tight_layout()
plt.savefig('RNG_histogram_plots.png') 
plt.show()
# Out:
# /var/folders/h6/9mpjzmxd77l7493g4210phz00000gn/T/ipykernel_6148/2461486888.py:11: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[0, 0].set_xticklabels(ax.get_xticks(), fontdict=tick_font)
# /var/folders/h6/9mpjzmxd77l7493g4210phz00000gn/T/ipykernel_6148/2461486888.py:12: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[0, 0].set_yticklabels(ax.get_yticks(), fontdict=tick_font)
# /var/folders/h6/9mpjzmxd77l7493g4210phz00000gn/T/ipykernel_6148/2461486888.py:23: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[0, 1].set_xticklabels(ax.get_xticks(), fontdict=tick_font)
# /var/folders/h6/9mpjzmxd77l7493g4210phz00000gn/T/ipykernel_6148/2461486888.py:24: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[0, 1].set_yticklabels(ax.get_yticks(), fontdict=tick_font)
# ...

# %% [markdown]
# ## Anomalous data in red

# %%
data_flagged_randm = pd.read_csv('rndtest_randm.out2', header=None, skiprows=3, names=['col1'])
df_flagged_randm = pd.DataFrame(data_flagged_randm)

data_flagged_rand = pd.read_csv('rndtest_rand.out2', header=None, skiprows=3, names=['col1'])
df_flagged_rand = pd.DataFrame(data_flagged_rand)

data_flagged_random_number = pd.read_csv('rndtest_random_number.out2', header=None, skiprows=3, names=['col1'])
df_flagged_random_number = pd.DataFrame(data_flagged_random_number)

data_flagged_randu = pd.read_csv('rndtest_randu.out2', header=None, skiprows=3, names=['col1'])
df_flagged_randu = pd.DataFrame(data_flagged_randu)

# %%
df_flagged_randm[['bin#', 'hits', 'std']] = df_flagged_randm['col1'].str.split(expand=True)
# Convert the columns to appropriate numeric types if needed
df_flagged_randm['bin#'] = df_flagged_randm['bin#'].astype(int)
df_flagged_randm['hits'] = df_flagged_randm['hits'].astype(float)
df_flagged_randm['stde'] = df_flagged_randm['std'].astype(float)
df_flagged_randm.drop(columns=['col1'], inplace=True)

df_flagged_rand[['bin#', 'hits', 'std']] = df_flagged_rand['col1'].str.split(expand=True)
# Convert the columns to appropriate numeric types if needed
df_flagged_rand['bin#'] = df_flagged_rand['bin#'].astype(int)
df_flagged_rand['hits'] = df_flagged_rand['hits'].astype(float)
df_flagged_rand['stde'] = df_flagged_rand['std'].astype(float)
df_flagged_rand.drop(columns=['col1'], inplace=True)

df_flagged_random_number[['bin#', 'hits', 'std']] = df_flagged_random_number['col1'].str.split(expand=True)
# Convert the columns to appropriate numeric types if needed
df_flagged_random_number['bin#'] = df_flagged_random_number['bin#'].astype(int)
df_flagged_random_number['hits'] = df_flagged_random_number['hits'].astype(float)
df_flagged_random_number['stde'] = df_flagged_random_number['std'].astype(float)
df_flagged_random_number.drop(columns=['col1'], inplace=True)

df_flagged_randu[['bin#', 'hits', 'std']] = df_flagged_randu['col1'].str.split(expand=True)
# Convert the columns to appropriate numeric types if needed
df_flagged_randu['bin#'] = df_flagged_randu['bin#'].astype(int)
df_flagged_randu['hits'] = df_flagged_randu['hits'].astype(float)
df_flagged_randu['stde'] = df_flagged_randu['std'].astype(float)
df_flagged_randu.drop(columns=['col1'], inplace=True)

# %%
len(df_flagged_randm)
# Out:
# 10

# %%
# Create a figure with a specific size (e.g., 10 inches wide and 8 inches tall)
fig, axs = plt.subplots(2, 2, figsize=(16, 16))

# Create individual plots for each subplot
axs[0, 0].scatter(df_rand['bin#'], df_rand['hits'], marker='o', color='blue', s=10, \
            alpha=0.5, label='normal')
axs[0, 0].scatter(df_flagged_rand['bin#'], df_flagged_rand['hits'], marker='o', \
            color='red', s=25, alpha=1, label='anomalous count: ' + str(len(df_flagged_rand)))
axs[0, 0].set_ylim(0, 170)  # Set the y-axis limits
axs[0, 0].set_title('rand', fontdict=title_font)
axs[0, 0].set_xlabel('Bin Index', fontdict=font)
axs[0, 0].set_ylabel('Hit Count', fontdict=font)
axs[0, 0].set_xticklabels(ax.get_xticks(), fontdict=tick_font)
axs[0, 0].set_yticklabels(ax.get_yticks(), fontdict=tick_font)
axs[0, 0].xaxis.set_major_formatter(StrMethodFormatter('{x:.0f}'))
axs[0, 0].yaxis.set_major_formatter(StrMethodFormatter('{x:.0f}'))
axs[0, 0].axhline(y=140, color='grey', linestyle='--')
axs[0, 0].axhline(y=60, color='grey', linestyle='--')
axs[0, 0].legend(loc='lower right', prop=legend_font)

axs[0, 1].scatter(df_randm['bin#'], df_randm['hits'], marker='o', color='blue', s=10, \
            alpha=0.5, label='normal')
axs[0, 1].scatter(df_flagged_randm['bin#'], df_flagged_randm['hits'], marker='o', \
            color='red', s=25, alpha=1, label='anomalous count: ' + str(len(df_flagged_randm)))
axs[0, 1].set_ylim(0, 170)  # Set the y-axis limits
axs[0, 1].set_title('randm', fontdict=title_font)
axs[0, 1].set_xlabel('Bin Index', fontdict=font)
axs[0, 1].set_ylabel('Hit Count', fontdict=font)
axs[0, 1].tick_params(axis='both', which='major', labelsize=18, length=6)  # Adjust label size and tick length
axs[0, 1].set_xticklabels(ax.get_xticks(), fontdict=tick_font)
axs[0, 1].set_yticklabels(ax.get_yticks(), fontdict=tick_font)
axs[0, 1].xaxis.set_major_formatter(StrMethodFormatter('{x:.0f}'))
axs[0, 1].yaxis.set_major_formatter(StrMethodFormatter('{x:.0f}'))
axs[0, 1].axhline(y=140, color='grey', linestyle='--')
axs[0, 1].axhline(y=60, color='grey', linestyle='--')
axs[0, 1].legend(loc='lower right', prop=legend_font)

axs[1, 0].scatter(df_randu['bin#'], df_randu['hits'], marker='o', color='blue', s=10, \
            alpha=0.5, label='normal')
axs[1, 0].scatter(df_flagged_randu['bin#'], df_flagged_randu['hits'], marker='o', \
            color='red', s=25, alpha=1, label='anomalous count: ' + str(len(df_flagged_randu)))
axs[1, 0].set_ylim(0, 170)  # Set the y-axis limits
axs[1, 0].set_title('randu', fontdict=title_font)
axs[1, 0].set_xlabel('Bin Index', fontdict=font)
axs[1, 0].set_ylabel('Hit Count', fontdict=font)
axs[1, 0].tick_params(axis='both', which='major', labelsize=18, length=6)  # Adjust label size and tick length
axs[1, 0].set_xticklabels(ax.get_xticks(), fontdict=tick_font)
axs[1, 0].set_yticklabels(ax.get_yticks(), fontdict=tick_font)
axs[1, 0].xaxis.set_major_formatter(StrMethodFormatter('{x:.0f}'))
axs[1, 0].yaxis.set_major_formatter(StrMethodFormatter('{x:.0f}'))
axs[1, 0].axhline(y=140, color='grey', linestyle='--')
axs[1, 0].axhline(y=60, color='grey', linestyle='--')
axs[1, 0].legend(loc='lower right', prop=legend_font)

axs[1, 1].scatter(df_random_number['bin#'], df_random_number['hits'], marker='o', color='blue', s=10, \
            alpha=0.5, label='normal')
axs[1, 1].scatter(df_flagged_random_number['bin#'], df_flagged_random_number['hits'], marker='o', \
            color='red', s=25, alpha=1, label='anomalous count: ' + str(len(df_flagged_random_number)))
axs[1, 1].set_ylim(0, 170)  # Set the y-axis limits
axs[1, 1].set_title('random_number', fontdict=title_font)
axs[1, 1].set_xlabel('Bin Index', fontdict=font)
axs[1, 1].set_ylabel('Hit Count', fontdict=font)
axs[1, 1].tick_params(axis='both', which='major', labelsize=18, length=6)  # Adjust label size and tick length
axs[1, 1].set_xticklabels(ax.get_xticks(), fontdict=tick_font)
axs[1, 1].set_yticklabels(ax.get_yticks(), fontdict=tick_font)
axs[1, 1].xaxis.set_major_formatter(StrMethodFormatter('{x:.0f}'))
axs[1, 1].yaxis.set_major_formatter(StrMethodFormatter('{x:.0f}'))
axs[1, 1].axhline(y=140, color='grey', linestyle='--')
axs[1, 1].axhline(y=60, color='grey', linestyle='--')
axs[1, 1].legend(loc='lower right', prop=legend_font)

fig.suptitle('Histogram of Random Numbers', fontproperties=suptitle_font, y=0.93)

plt.gcf().set_facecolor('white')
# plt.tight_layout()
plt.savefig('RNG_histogram_flagged_plots.png') 
plt.show()
# Out:
# /var/folders/h6/9mpjzmxd77l7493g4210phz00000gn/T/ipykernel_6148/4114271435.py:13: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[0, 0].set_xticklabels(ax.get_xticks(), fontdict=tick_font)
# /var/folders/h6/9mpjzmxd77l7493g4210phz00000gn/T/ipykernel_6148/4114271435.py:14: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[0, 0].set_yticklabels(ax.get_yticks(), fontdict=tick_font)
# /var/folders/h6/9mpjzmxd77l7493g4210phz00000gn/T/ipykernel_6148/4114271435.py:30: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[0, 1].set_xticklabels(ax.get_xticks(), fontdict=tick_font)
# /var/folders/h6/9mpjzmxd77l7493g4210phz00000gn/T/ipykernel_6148/4114271435.py:31: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[0, 1].set_yticklabels(ax.get_yticks(), fontdict=tick_font)
# ...

# %% [markdown]
# ## Correlation betwen triplets

# %%
data_triplet = pd.read_csv('triplet_test_randu.out1', header=None, names=['col1'])
df_triplet = pd.DataFrame(data_triplet)

# %%
df_triplet[['x', 'y', 'z']] = df_triplet['col1'].str.split(expand=True)
# Convert the columns to appropriate numeric types if needed
df_triplet['x'] = df_triplet['x'].astype(float)
df_triplet['y'] = df_triplet['y'].astype(float)
df_triplet['z'] = df_triplet['z'].astype(float)
df_triplet.drop(columns=['col1'], inplace=True)

# %%
df_triplet
# Out:
#             x         y         z
# 0    0.000183  0.000824  0.003296
# 1    0.012360  0.044495  0.155732
# 2    0.533939  0.802042  0.006802
# 3    0.822440  0.873416  0.838542
# 4    0.170501  0.476134  0.322291
# ..        ...       ...       ...
# 995  0.532247  0.952058  0.922122
# 996  0.964212  0.486172  0.239126
# 997  0.059204  0.203096  0.685733
# 998  0.286540  0.547639  0.706973
# 999  0.313089  0.515773  0.276843
#
# [1000 rows x 3 columns]
